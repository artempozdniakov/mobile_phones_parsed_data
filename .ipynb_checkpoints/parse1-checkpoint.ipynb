# %%
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
header = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    "content-type":"text",
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_html(link):
    time.sleep(1)
    req = requests.get(link, headers=header)
    return req.text

# %%
get_html('https://hotline.ua/mobile/mobilnye-telefony-i-smartfony/?p=0')[:4000]
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n        <script>\n    // Функция аналог jQuery(document).ready(function(){})\n    function gtm_documentReady(callback) {\n        if (document.readyState !== \'loading\' && document.readyState) {\n            callback();\n        } else {\n            document.addEventListener("DOMContentLoaded", callback);\n        }\n    };\n\n    // Функция установки куки\n    function gtm_setCookie(name, value, maxAge) {\n        var options = {\n            path: \'/\', secure: true, \'max-age\': maxAge\n        };\n\n        if (options.expires instanceof Date) {\n            options.expires = options.expires.toUTCString();\n        }\n\n        var updatedCookie = encodeURIComponent(name) + "=" + encodeURIComponent(value);\n\n        for (var optionKey in options) {\n            updatedCookie += "; " + optionKey;\n            var optionValue = options[optionKey];\n            if (optionValue !== true) {\n            updatedCookie += "=" + optionValue;\n            }\n        }\n\n        document.cookie = updatedCookie;\n    };\n    // Функция получения куки\n    function gtm_getCookie(name) {\n        var matches = document.cookie.match(new RegExp(\n            "(?:^|; )" + name.replace(/([\\.$?*|{}\\(\\)\\[\\]\\\\\\/\\+^])/g, \'\\\\$1\') + "=([^;]*)"\n        ));\n        return matches ? decodeURIComponent(matches[1]) : undefined;\n    };\n    // Функция удаления куки\n    function gtm_deleteCookie(name) {\n        gtm_setCookie(name, "", -1);\n    };\n\n    (function(){\n        var match = document.cookie.match(\'(?:^|;)\\\\s*_ga=([^;]*)\');\n        var raw = (match) ? decodeURIComponent(match[1]) : null;\n        if (raw) match = raw.match(/(\\d+\\.\\d+)$/);\n        var gacid = (match) ? match[1] : null;\n        if (gacid) window.ga_client_id = gacid;\n    })();\n\n    dataLayer = [{"pageType":"Catalog","productCategoryID":11,"pageContent":"Priceline","goContext":"Goprice","productCategoryName":"\\u0421\\u043c\\u0430\\u0440\\u0442\\u0444\\u043e\\u043d\\u044b \\u0438 \\u043c\\u043e\\u0431\\u0438\\u043b\\u044c\\u043d\\u044b\\u0435 \\u0442\\u0435\\u043b\\u0435\\u0444\\u043e\\u043d\\u044b","productCategoryIntermediate":"\\u0421\\u043c\\u0430\\u0440\\u0442\\u0444\\u043e\\u043d\\u044b \\u0438 \\u043c\\u043e\\u0431\\u0438\\u043b\\u044c\\u043d\\u044b\\u0435 \\u0442\\u0435\\u043b\\u0435\\u0444\\u043e\\u043d\\u044b","productCategoryGroupName":"\\u0421\\u043c\\u0430\\u0440\\u0442\\u0444\\u043e\\u043d\\u044b, \\u0422\\u0435\\u043b\\u0435\\u0444\\u043e\\u043d\\u044b","productQuantity":1795,"pageLayout":"row","pageMode":"goods","CatFirst10Prod":["21302259","20785734","21106246","17852983","20986562","20191727","14296986","21594662","21302270","17852989"],"clientID":null,"userLanguage":null,"userAuth":0,"containerId":"GTM-MLHSDC"}];\n</script>\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n        new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\', "GTM-MLHSDC");</script>\n\n    <!-- Facebook Pixel Code -->\n<script>\n    setTimeout(function () {\n        !function(f,b,e,v,n,t,s)\n        {if(f.fbq)return;n=f.fbq=function(){n.callMethod?\n                n.callMethod.apply(n,arguments):n.queue.push(arguments)};\n            if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version=\'2.0\';\n            n.queue=[];t=b.createElement(e);t.async=!0;\n            t.src=v;s=b.getElementsByTagName(e)[0];\n            s.parentNode.insertBefore(t,s)}(window, document,\'script\',\n                \'https://connect.facebook.net/en_US/fbevents.js\');\n        fbq(\'init\', \'508930199650207\');\n        fbq(\'track\', \'PageView\');\n    }, 3000);\n</script>\n\n<noscript><img height="1" width="1" style="display:none"\n               src="https://www.facebook ...

# %%
def get_pages_amount(code):
    soup = BeautifulSoup(code)
    pages = soup.find('div', class_='pages-list cell-sm').find_all('a', class_='pages')[-1].get('href').split('=')[1]
    return pages

# %%
pages_amount = get_pages_amount(get_html('https://hotline.ua/mobile/mobilnye-telefony-i-smartfony/?p=1'))
pages_amount
# Out:
# '74'

# %%
base_link = 'https://hotline.ua/mobile/mobilnye-telefony-i-smartfony/?p='

# %%
def get_data(code, ind=0):
    soup = BeautifulSoup(code)
    
    phones = soup.find_all('li', class_='product-item')
    data = pd.DataFrame({'name': [], 'best_price': [], 'price_range': [], 'salers_amount': [], 'popularity': []})
    for phone in phones:
        try:
            name = phone.find('div', class_='item-info').find('p', class_='h4').find('a').text.replace('\n', '')
        except:
            name = None
            
        try:
            best_price = phone.find('div', class_='item-price stick-bottom').find('span', class_='value').text
        except:
            best_price = None
        
        try:
            price_range = phone.find('div', class_='item-price stick-bottom').find('div', class_='text-sm').text
        except:
            price_range = None
            
        try: 
            salers_amount = phone.find('div', class_='item-price stick-bottom').find('a', class_='link').text
        except:
            salers_amount = None
    
        try:
            stats = phone.find('div', class_='item-info').find('div', class_='text').find('p').text.strip()
        except: 
            stats = None
        t = pd.Series([name, best_price, price_range, salers_amount, stats])
        df_temp = pd.DataFrame({'name': t[0], 'best_price': t[1], 'price_range': t[2], 'salers_amount': t[3], 'popularity': t[4]}, index=range(ind, ind+1))
        ind += 1
        data = data.append(df_temp)
    return data, ind

# %%
result = pd.DataFrame({'name': [], 'best_price': [], 'price_range': [], 'salers_amount': [], 'popularity': []})
ind = 0
for i in tqdm(np.arange(75)):
    link = base_link + str(i)
    t, ind = get_data(get_html(link), ind)
    result = result.append(t)
# Out:
# 100%|██████████| 75/75 [05:32<00:00,  4.44s/it]

# %%
copy_res = result

# %%
result = copy_res

# %%
result.shape
# Out:
# (1275, 5)

# %%
result.shape
# Out:
# (1275, 5)

# %%
result.name = result.name.str.strip()

# %%
result.isna().sum()
# Out:
# name              51
# best_price        51
# price_range      311
# salers_amount     51
# popularity        51
# dtype: int64

# %%
result = result.drop(result[result.name.isna()].index)

# %%
result.best_price = result.best_price.str.replace('\xa0', '')

# %%
result.best_price = result.best_price.astype('float')

# %%
brands = []
model_names = []
for brand in result.name:
    brands.append(brand[:brand.index(" ")])
    model_names.append(brand[brand.index(" ")+1:])

# %%
result['brand_name'] = brands
result['model_name'] = model_names

# %%
result.brand_name.unique()
# Out:
# array(['Apple', 'Google', 'Xiaomi', 'Samsung', 'OnePlus', 'realme',
#        'Motorola', 'HUAWEI', 'Meizu', 'Nokia', 'OPPO', 'Sony', 'ASUS',
#        'LG', 'Oukitel', 'CAT', 'ZTE', 'Tecno', 'DOOGEE', 'Honor',
#        'Ulefone', 'Blackview', 'Sigma', 'vivo', 'Philips', 'Cubot',
#        'Lenovo', 'Rezone', 'Nomi', 'BlackBerry', 'Fly', 'ERGO', 'UMIDIGI',
#        'AGM', 'Vernee', 'ALCATEL', 'Maxcom', 'Land', 'HTC', '2E', 'NUU',
#        'Sharp', 'Archos', 'Astro', 'Vodafone', 'Elephone', 'Microsoft',
#        'Globex', 'S-TELL', 'Assistant', 'Jinga', 'Smartex', 'Bravis',
#        'MAFAM', 'Viaan', 'Coolpad', 'General', 'Prestigio', 'Bluboo',
#        'Crosscall', 'iOutdoor', 'LEAGOO', 'KENEKSI', 'myPhone'],
#       dtype=object)

# %%
model_names[:3]
# Out:
# ['iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)',
#  'Pixel 4a 6/128GB Just Black',
#  'Poco X3 NFC 6/128GB Cobalt Blue']

# %%
result = result.drop(columns='name')

# %%
result
# Out:
#       best_price          price_range  \
# 0        33992.0  31 849 – 42 999 грн
# 1        12106.0  11 740 – 12 999 грн
# 2         7152.0    6 836 – 7 999 грн
# 3        20889.0  18 200 – 26 499 грн
# 4         9620.0   8 555 – 10 394 грн
# ...          ...                  ...
# 1270       326.0        222 – 373 грн
# 1271      5600.0                 None
# 1272      2999.0                 None
# 1273      5628.0    5 297 – 6 584 грн
# 1274       299.0                 None
#
#                                          salers_amount  \
# 0                                 Всі пропозиції (101)
# 1                                  Всі пропозиції (37)
# 2                                  Всі пропозиції (59)
# 3                                  Всі пропозиції (93)
# 4                                  Всі пропозиції (55)
# ...                                                ...
# 1270                               Всі пропозиції (14)
# 1271  \n                    EuroMade\n
# 1272    \n                    TTT.UA\n
# 1273                               Всі пропозиції (11)
# 1274    \n                    S-TELL\n
#
#                                              popularity brand_name  \
# 0     Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...      Apple
# 1     Смартфон •   1 SIM •   екран: 5,81" •   OLED •...     Google
# 2     Смартфон •   2 або 1 + карта пам'яті SIM •   е...     Xiaomi
# 3     Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...      Apple
# 4     Смартфон •   2 SIM •   екран: 6,7" •   Super A...    Samsung
# ...                                                 ...        ...
# 1270  Мобільний телефон •   2 SIM •   екран: 2,4" • ...      Viaan
# 1271  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...    myPhone
# 1272  Смартфон •   2 або 1 + карта пам'яті SIM •   е...      Sigma
# 1273  Смартфон •   2 або 1 + карта пам'яті SIM •   е...        AGM
# 1274  Мобільний телефон •   2 SIM •   екран: 1,8" • ...     S-TELL
#
#                                           model_name
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)
# 1                        Pixel 4a 6/128GB Just Black
# 2                    Poco X3 NFC 6/128GB Cobalt Blue
# 3                       iPhone 11 64GB Black (MWLT2)
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)
# ...                                              ...
# 1270                                    V241 (Black)
# 1271                             Hammer Energy Black
# 1272                mobile X-treme PQ24 Black/Orange
# 1273                               A10 6/128GB Black
# 1274                                      S1-07 Gold
#
# [1224 rows x 6 columns]

# %%
result.price_range = result.price_range.str.replace("грн", '')
result.price_range = result.price_range.str.replace('\xa0', '')
result
# Out:
#       best_price  price_range  \
# 0        33992.0  31849–42999
# 1        12106.0  11740–12999
# 2         7152.0    6836–7999
# 3        20889.0  18200–26499
# 4         9620.0   8555–10394
# ...          ...          ...
# 1270       326.0      222–373
# 1271      5600.0         None
# 1272      2999.0         None
# 1273      5628.0    5297–6584
# 1274       299.0         None
#
#                                          salers_amount  \
# 0                                 Всі пропозиції (101)
# 1                                  Всі пропозиції (37)
# 2                                  Всі пропозиції (59)
# 3                                  Всі пропозиції (93)
# 4                                  Всі пропозиції (55)
# ...                                                ...
# 1270                               Всі пропозиції (14)
# 1271  \n                    EuroMade\n
# 1272    \n                    TTT.UA\n
# 1273                               Всі пропозиції (11)
# 1274    \n                    S-TELL\n
#
#                                              popularity brand_name  \
# 0     Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...      Apple
# 1     Смартфон •   1 SIM •   екран: 5,81" •   OLED •...     Google
# 2     Смартфон •   2 або 1 + карта пам'яті SIM •   е...     Xiaomi
# 3     Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...      Apple
# 4     Смартфон •   2 SIM •   екран: 6,7" •   Super A...    Samsung
# ...                                                 ...        ...
# 1270  Мобільний телефон •   2 SIM •   екран: 2,4" • ...      Viaan
# 1271  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...    myPhone
# 1272  Смартфон •   2 або 1 + карта пам'яті SIM •   е...      Sigma
# 1273  Смартфон •   2 або 1 + карта пам'яті SIM •   е...        AGM
# 1274  Мобільний телефон •   2 SIM •   екран: 1,8" • ...     S-TELL
#
#                                           model_name
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)
# 1                        Pixel 4a 6/128GB Just Black
# 2                    Poco X3 NFC 6/128GB Cobalt Blue
# 3                       iPhone 11 64GB Black (MWLT2)
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)
# ...                                              ...
# 1270                                    V241 (Black)
# 1271                             Hammer Energy Black
# 1272                mobile X-treme PQ24 Black/Orange
# 1273                               A10 6/128GB Black
# 1274                                      S1-07 Gold
#
# [1224 rows x 6 columns]

# %%
result = result.fillna('none')

# %%
lowest_price = [] 
highest_price = []
for p_range in result.price_range:
    try:
        p_range.index('–')
        lowest_price.append(int(p_range.split('–')[0]))
        highest_price.append(int(p_range.split('–')[1]))
    except:
        lowest_price.append(None)
        highest_price.append(None)

# %%
result['lowest_price'] = lowest_price
result['highest_price'] = highest_price

# %%
len(lowest_price)
# Out:
# 1224

# %%
result = result.drop(columns='price_range')

# %%
result
# Out:
#       best_price                                     salers_amount  \
# 0        33992.0                              Всі пропозиції (101)
# 1        12106.0                               Всі пропозиції (37)
# 2         7152.0                               Всі пропозиції (59)
# 3        20889.0                               Всі пропозиції (93)
# 4         9620.0                               Всі пропозиції (55)
# ...          ...                                               ...
# 1270       326.0                               Всі пропозиції (14)
# 1271      5600.0  \n                    EuroMade\n
# 1272      2999.0    \n                    TTT.UA\n
# 1273      5628.0                               Всі пропозиції (11)
# 1274       299.0    \n                    S-TELL\n
#
#                                              popularity brand_name  \
# 0     Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...      Apple
# 1     Смартфон •   1 SIM •   екран: 5,81" •   OLED •...     Google
# 2     Смартфон •   2 або 1 + карта пам'яті SIM •   е...     Xiaomi
# 3     Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...      Apple
# 4     Смартфон •   2 SIM •   екран: 6,7" •   Super A...    Samsung
# ...                                                 ...        ...
# 1270  Мобільний телефон •   2 SIM •   екран: 2,4" • ...      Viaan
# 1271  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...    myPhone
# 1272  Смартфон •   2 або 1 + карта пам'яті SIM •   е...      Sigma
# 1273  Смартфон •   2 або 1 + карта пам'яті SIM •   е...        AGM
# 1274  Мобільний телефон •   2 SIM •   екран: 1,8" • ...     S-TELL
#
#                                           model_name  lowest_price  \
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)       31849.0
# 1                        Pixel 4a 6/128GB Just Black       11740.0
# 2                    Poco X3 NFC 6/128GB Cobalt Blue        6836.0
# 3                       iPhone 11 64GB Black (MWLT2)       18200.0
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)        8555.0
# ...                                              ...           ...
# 1270                                    V241 (Black)         222.0
# 1271                             Hammer Energy Black           NaN
# 1272                mobile X-treme PQ24 Black/Orange           NaN
# 1273                               A10 6/128GB Black        5297.0
# 1274                                      S1-07 Gold           NaN
#
#       highest_price
# 0           42999.0
# 1           12999.0
# 2            7999.0
# 3           26499.0
# 4           10394.0
# ...             ...
# 1270          373.0
# 1271            NaN
# 1272            NaN
# 1273         6584.0
# 1274            NaN
#
# [1224 rows x 7 columns]

# %%
salers_am = []
for salers in result.salers_amount:
    try:
        salers.index('(')
        salers_am.append(salers[salers.index('(')+1:salers.index(')')])
    except:
        salers_am.append(1)

# %%
result.salers_amount = salers_am

# %%
result
# Out:
#       best_price salers_amount  \
# 0        33992.0           101
# 1        12106.0            37
# 2         7152.0            59
# 3        20889.0            93
# 4         9620.0            55
# ...          ...           ...
# 1270       326.0            14
# 1271      5600.0             1
# 1272      2999.0             1
# 1273      5628.0            11
# 1274       299.0             1
#
#                                              popularity brand_name  \
# 0     Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...      Apple
# 1     Смартфон •   1 SIM •   екран: 5,81" •   OLED •...     Google
# 2     Смартфон •   2 або 1 + карта пам'яті SIM •   е...     Xiaomi
# 3     Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...      Apple
# 4     Смартфон •   2 SIM •   екран: 6,7" •   Super A...    Samsung
# ...                                                 ...        ...
# 1270  Мобільний телефон •   2 SIM •   екран: 2,4" • ...      Viaan
# 1271  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...    myPhone
# 1272  Смартфон •   2 або 1 + карта пам'яті SIM •   е...      Sigma
# 1273  Смартфон •   2 або 1 + карта пам'яті SIM •   е...        AGM
# 1274  Мобільний телефон •   2 SIM •   екран: 1,8" • ...     S-TELL
#
#                                           model_name  lowest_price  \
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)       31849.0
# 1                        Pixel 4a 6/128GB Just Black       11740.0
# 2                    Poco X3 NFC 6/128GB Cobalt Blue        6836.0
# 3                       iPhone 11 64GB Black (MWLT2)       18200.0
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)        8555.0
# ...                                              ...           ...
# 1270                                    V241 (Black)         222.0
# 1271                             Hammer Energy Black           NaN
# 1272                mobile X-treme PQ24 Black/Orange           NaN
# 1273                               A10 6/128GB Black        5297.0
# 1274                                      S1-07 Gold           NaN
#
#       highest_price
# 0           42999.0
# 1           12999.0
# 2            7999.0
# 3           26499.0
# 4           10394.0
# ...             ...
# 1270          373.0
# 1271            NaN
# 1272            NaN
# 1273         6584.0
# 1274            NaN
#
# [1224 rows x 7 columns]

# %%
result['stats'] = result.popularity

# %%
result = result.drop(columns='popularity')

# %%
sigma = result[result.brand_name == 'Sigma']
sigma.brand_name = 'Sigma mobile'
models = []
for name in sigma.model_name:
    models.append(name[7:])
sigma.model_name = models
# Out:
# /Users/artempozdniakov/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
result[result.brand_name == 'Sigma'] = sigma

# %%
result
# Out:
#       best_price salers_amount    brand_name  \
# 0        33992.0           101         Apple
# 1        12106.0            37        Google
# 2         7152.0            59        Xiaomi
# 3        20889.0            93         Apple
# 4         9620.0            55       Samsung
# ...          ...           ...           ...
# 1270       326.0            14         Viaan
# 1271      5600.0             1       myPhone
# 1272      2999.0             1  Sigma mobile
# 1273      5628.0            11           AGM
# 1274       299.0             1        S-TELL
#
#                                           model_name  lowest_price  \
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)       31849.0
# 1                        Pixel 4a 6/128GB Just Black       11740.0
# 2                    Poco X3 NFC 6/128GB Cobalt Blue        6836.0
# 3                       iPhone 11 64GB Black (MWLT2)       18200.0
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)        8555.0
# ...                                              ...           ...
# 1270                                    V241 (Black)         222.0
# 1271                             Hammer Energy Black           NaN
# 1272                       X-treme PQ24 Black/Orange           NaN
# 1273                               A10 6/128GB Black        5297.0
# 1274                                      S1-07 Gold           NaN
#
#       highest_price                                              stats
# 0           42999.0  Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...
# 1           12999.0  Смартфон •   1 SIM •   екран: 5,81" •   OLED •...
# 2            7999.0  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 3           26499.0  Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...
# 4           10394.0  Смартфон •   2 SIM •   екран: 6,7" •   Super A...
# ...             ...                                                ...
# 1270          373.0  Мобільний телефон •   2 SIM •   екран: 2,4" • ...
# 1271            NaN  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...
# 1272            NaN  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 1273         6584.0  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 1274            NaN  Мобільний телефон •   2 SIM •   екран: 1,8" • ...
#
# [1224 rows x 7 columns]

# %%
result.stats[100].split('•   ')
# Out:
# ['Смартфон ',
#  '2 SIM ',
#  'екран: 6,5" ',
#  'OLED ',
#  '2688x1242 ',
#  "вбудована пам'ять: 256 ГБ ",
#  "оперативна пам'ять: 4 ГБ ",
#  'процесор: Apple A12 Bionic ',
#  'ОС: iOS ',
#  'акумулятор: 3174 мАг (незнімний) ',
#  'камера: 12 (f / 1.8) + 12 (f / 2.2) Мп ',
#  'колір: золотий ',
#  'NFC: + (Apple Pay)\n                        • 09.2018\n\n                                                    • Модель з лінійки  iPhone XS Max']

# %%
screen_size = []
memory_size = []
battery_size = []
release_date = []
system = []

for i in result.stats:
    if "екран:" in i:
        screen_size.append(i.split('екран:')[1][:5])
    else:
        screen_size.append(None)
    if "вбудована пам'ять:" in i:
        memory_size.append(i.split("вбудована пам'ять:")[1][:11])
    else:
        memory_size.append(None)
    if "акумулятор:" in i:
        battery_size.append(i.split("акумулятор:")[1][:22])
    else:
        battery_size.append(None)
    if ".20" in i:
        release_date.append(i.split(".20")[0][-3:]+".20"+i.split(".20")[1][:3])
    else:
        release_date.append(None)
    if "ОС:" in i:
        system.append(i.split("ОС:")[1][:11])
    else:
        system.append(None)

# %%
release_date[1001]
# Out:
# ' 09.2016\n'

# %%
result.stats[101]
# Out:
# 'Смартфон •   2 або 1 + карта пам\'яті SIM •   екран: 5,5" •   IPS •   1920x1080 •   вбудована пам\'ять: 64 ГБ •   оперативна пам\'ять: 4 ГБ •   процесор: Qualcomm Snapdragon 625 + GPU Adreno 506 •   ОС: Android 6.0 •   акумулятор: Li-Ion, 4100 мАч (незнімний) •   камера: 13 (F2.0) Мп •   колір: чорний\n                        • 05.2017\n\n                                                    • Модель з лінійки  Redmi Note 4x'

# %%
result.shape
# Out:
# (1224, 12)

# %%
result['screen_size'] = screen_size
result['memory_size'] = memory_size
result['battery_size'] = battery_size
result['release_date'] = release_date
result['system'] = system

# %%
result
# Out:
#       best_price salers_amount    brand_name  \
# 0        33992.0           101         Apple
# 1        12106.0            37        Google
# 2         7152.0            59        Xiaomi
# 3        20889.0            93         Apple
# 4         9620.0            55       Samsung
# ...          ...           ...           ...
# 1270       326.0            14         Viaan
# 1271      5600.0             1       myPhone
# 1272      2999.0             1  Sigma mobile
# 1273      5628.0            11           AGM
# 1274       299.0             1        S-TELL
#
#                                           model_name  lowest_price  \
# 0     iPhone 12 Pro 128GB Pacific Blue (MGMN3/MGLR3)       31849.0
# 1                        Pixel 4a 6/128GB Just Black       11740.0
# 2                    Poco X3 NFC 6/128GB Cobalt Blue        6836.0
# 3                       iPhone 11 64GB Black (MWLT2)       18200.0
# 4             Galaxy M51 6/128GB Black (SM-M515FZKD)        8555.0
# ...                                              ...           ...
# 1270                                    V241 (Black)         222.0
# 1271                             Hammer Energy Black           NaN
# 1272                       X-treme PQ24 Black/Orange           NaN
# 1273                               A10 6/128GB Black        5297.0
# 1274                                      S1-07 Gold           NaN
#
#       highest_price                                              stats  \
# 0           42999.0  Смартфон •   2 SIM •   екран: 6,1" •   OLED • ...
# 1           12999.0  Смартфон •   1 SIM •   екран: 5,81" •   OLED •...
# 2            7999.0  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 3           26499.0  Смартфон •   2 SIM •   екран: 6,1" •   IPS •  ...
# 4           10394.0  Смартфон •   2 SIM •   екран: 6,7" •   Super A...
# ...             ...                                                ...
# 1270          373.0  Мобільний телефон •   2 SIM •   екран: 2,4" • ...
# 1271            NaN  Смартфон •   2 SIM •   екран: 5" •   IPS •   1...
# 1272            NaN  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 1273         6584.0  Смартфон •   2 або 1 + карта пам'яті SIM •   е...
# 1274            NaN  Мобільний телефон •   2 SIM •   екран: 1,8" • ...
#
#      screen_size  memory_size            battery_size release_date  \
# 0           6,1"   128 ГБ •     2815 мАг (незнімний)     10.2020\n
# 1           5,81   128 ГБ •     Li-Pol, 3140 мАг (нез    08.2020\n
# 2           6,67   128 ГБ •     5160 мАг (незнімний)     09.2020\n
# 3           6,1"   64 ГБ •      3110 мАг (незнімний)     09.2019\n
# 4           6,7"   128 ГБ •     7000 мАг (незнімний)     09.2020\n
# ...          ...          ...                     ...          ...
# 1270        2,4"   0,032 ГБ •   1000 мАг (знімний) •     09.2016\n
# 1271        5" •   16 ГБ •      Li-Pol, 5000 мАг (нез      01.2017
# 1272        5" •   8 ГБ •   о   Li-Pol 5000 mAh (незм    01.2017\n
# 1273        5,7"   128 ГБ •     4400 мАг (незнімний)       10.2020
# 1274        1,8"         None   Li-Ion, 1000 мАг •       06.2017\n
#
#            system
# 0      Apple iOS
# 1      Android 10
# 2      Android 10
# 3      iOS •   ак
# 4      Android 10
# ...           ...
# 1270         None
# 1271   Android 6.
# 1272   Android 7.
# 1273   Android 9.
# 1274         None
#
# [1224 rows x 12 columns]

# %%
result.to_csv('ds.csv')
